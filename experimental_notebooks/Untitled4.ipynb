# %%
import rasterio
from rasterio.plot import show
from matplotlib import pyplot as plt

# %%
img = rasterio.open('out/cutout_kaunas.tif')
show(img)
# Out:
# <AxesSubplot:>

# %%
img.crs
# Out:
# CRS.from_epsg(4326)

# %%
img.descriptions
# Out:
# (None, None, None)

# %%
img.transform * (img.width, img.height)
# Out:
# (709800.0, 5990220.0)

# %%
img.crs
# Out:
# CRS.from_epsg(4326)
