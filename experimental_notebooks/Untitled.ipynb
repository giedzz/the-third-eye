# %%
import rioxarray
import xarray
xds = xarray.open_dataarray("out/out_kaunas_sentinel.tif")

# %%
xds.plot()
# Out:
# (array([3.59825248e+08, 1.39623500e+06, 3.30511000e+05, 1.01162000e+05,
#         2.58140000e+04, 1.89300000e+03, 1.19000000e+02, 5.80000000e+01,
#         3.00000000e+01, 1.30000000e+02]),
#  array([    0. ,  1750.4,  3500.8,  5251.2,  7001.6,  8752. , 10502.4,
#         12252.8, 14003.2, 15753.6, 17504. ], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
minx, miny = 54.8217649993685, 23.7922346
maxx, maxy = 54.9597227994084, 24.0968447
xdsc = xds.rio.clip_box(
    minx=minx,
    miny=miny,
    maxx=maxx,
    maxy=maxy,
)
# Out:
# ---------------------------------------------------------------------------
# NoDataInBounds                            Traceback (most recent call last)
# /tmp/ipykernel_132142/4024573823.py in <module>
#       1 minx, miny = 54.8217649993685, 23.7922346
#       2 maxx, maxy = 54.9597227994084, 24.0968447
# ----> 3 xdsc = xds.rio.clip_box(
#       4     minx=minx,
#       5     miny=miny,
#
# ~/anaconda3/envs/the_third_eye/lib/python3.9/site-packages/rioxarray/raster_array.py in clip_box(self, minx, miny, maxx, maxy, auto_expand, auto_expand_limit)
#     677                 raise window_error
#     678             if cl_array.rio.width < 1 or cl_array.rio.height < 1:
# --> 679                 raise NoDataInBounds(
#     680                     f"No data found in bounds.{_get_data_var_message(self._obj)}"
#     681                 )
#
# NoDataInBounds: No data found in bounds. Data variable: band_data

# %%
xds
# Out:
# <xarray.DataArray 'band_data' (band: 3, y: 10980, x: 10980)>
# [361681200 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 6e+05 6e+05 6e+05 ... 7.098e+05 7.098e+05 7.098e+05
#   * y            (y) float64 6.1e+06 6.1e+06 6.1e+06 ... 5.99e+06 5.99e+06
#     spatial_ref  int64 ...

# %%
rds = rioxarray.open_rasterio("out/out_kaunas_sentinel.tif")

# %%
rds
# Out:
# <xarray.DataArray (band: 3, y: 10980, x: 10980)>
# [361681200 values with dtype=uint16]
# Coordinates:
#   * band         (band) int64 1 2 3
#   * x            (x) float64 6e+05 6e+05 6e+05 ... 7.098e+05 7.098e+05 7.098e+05
#   * y            (y) float64 6.1e+06 6.1e+06 6.1e+06 ... 5.99e+06 5.99e+06
#     spatial_ref  int64 0
# Attributes:
#     scale_factor:  1.0
#     add_offset:    0.0
